# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
# 비교연산자
print(3 > 1)
# Out:
# True

# %%
# 숫자가 같은지 다른지 비교
print(10 == 10)
print(10 != 5)
# Out:
# True
# True

# %%
print("Python" == "Python")
print("Python" == "python")
# Out:
# True
# False

# %%
# 부등호 사용하기
print(10 > 20)
print(10 < 20)
print(10 >= 20)
print(10 <= 20)
# Out:
# False
# True
# False
# True

# %%
print(1 == 1.0)
# print(1 is 1.0) # 같은 주소를 가르키는지
print(id(1))
print(id(1.0))
# Out:
# True
# 140714538099832
# 2693688225008

# %%
# 논리 연산자 사용하기
print(True and True and True)
print(True and False and True)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True or True)
print(True or False or True)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
print(not True)
False and False or True
# Out:
# False
# True

# %%
# 논리 연산자와 비교연산자를 함께 사용하기
print(10 == 10 and 10 != 5)
print(10 > 5 or 10 < 5)
print(not 10 > 5)
print(not 1 is 1.0)
# Out:
# True
# True
# False
# True
# <>:5: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\lgiht\AppData\Local\Temp\ipykernel_10612\4171537223.py:5: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
# 연습문제 
korean = 92
english = 47
mathematics = 86
science = 81

print(korean >= 50 and english >= 50 and mathematics >= 50 and science >= 50)
# Out:
# False

# %%
# 심사문제
korean, english, mathematics, science = map(int, input().split())
print(korean >= 90 and english > 80 and mathematics > 85 and science >= 80)
# Out:
# False
