# %%
# 값을 여러개 출력하기
print(1, 2, 3)
print("hello", "Python")
# Out:
# 1 2 3
# hello Python

# %%
# sep로 값 사이에 문자넣기
print(1, 2, 3)
print(1, 2, 3, sep=", ")
# Out:
# 1 2 3
# 1, 2, 3

# %%
print("Hello", "Python")
print("Hello", "Python", sep="")
# Out:
# Hello Python
# HelloPython

# %%
print(1920, 1080, sep="x")
# Out:
# 1920x1080

# %%
# 줄바꿈 활용
