# %%
# 튜플은 어떻게 만들까

t1 = ()
t2 = (1,) #반드시 콤마를 붙여야 한다.
t3 = (1, 2, 3)
t4 = 1, 2, 3 #괄호를 생략할 수 있다.
t5 = ("a", "b", ("ab", "cd")) #튜플 안에 튜플을 넣을 수 있다.
t6 = tuple()


type(t3)
# Out:
# tuple

# %%
t1 = (10, )
t2 = 10,

print(type(t1))
print(type(t2))

d1 = 10  # d1 = (10) 이랑 같음
print(type(d1))

num = 10, 20
print(type(num))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'int'>
# <class 'tuple'>

# %%
## 튜플의 요소값을 지우거나 변경하려고 하면?
t1 = 1, 2, "a", "b"
# t1[2] = 10
# del t1[2] 
# 튜플은 요소를 지우거나 변경할수 없다.

# %%
## 튜플인덱싱
t1 = (1, 2, "a", "b")
print(t1[0])
print(t1[-1])
# Out:
# 1
# b

# %%
## 튜플 슬라이싱
t1 = (1, 2, ("a", "b"))
t1[1:]
# Out:
# (2, ('a', 'b'))

# %%
## 튜플 더하기
t1 = (1, 2, "a", "b")
t2 = (3, 4)

print(t1 + t2 ) # 수정의 개념이 아닌 기존 튜플은 놔두고 새로운 튜플을 만든거라 가능
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
t2 = (3, 4)
t2 *3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
t2
# Out:
# (3, 4)

# %%
t1 = (1, 2, "a", "b")
len(t1)
# Out:
# 3
