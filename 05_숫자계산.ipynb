# %%
# 사칙연산
1+1
# Out:
# 2

# %%
5 / 2
# Out:
# 2.5

# %%
4 / 2
# Out:
# 2.0

# %%
# 소숫점 이하를 버리는 연산자 //
print(5 // 2)
print(5.5 // 2)
# Out:
# 2
# 2.0

# %%
# 나머지를 구하는 연산자 %
print(5 % 2)
print(7 % 3)
# Out:
# 1
# 1

# %%
# 거듭제곱을 구하는 연산자 **
print(2 ** 10)
10**10
# Out:
# 1024
# 10000000000

# %%
# 값을 정수로 만들기, 소수점 이하 버리기
print(int(3.3))
print(int(5 / 2))
print(int("1"))
# Out:
# 3
# 2
# 1

# %%
# 객체의 자료형 알아내기
print(type(10))
print(type("1"))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# 실수 계산하기
print(3.5 + 2.1)
# Out:
# 5.6

# %%
# 실수와 정수를 함께 계산하면
print(4.2 + 5)
# Out:
# 9.2

# %%
# 값을 실수로 만들기
print(float(5))
print(float(1+2))
print(float("5.3"))
# Out:
# 5.0
# 3.0
# 5.3

# %%
# 괄호 사용하기, 괄호 없어도 기본 사칙연산 우선순위는 지켜짐
print((35 + 1) * 2)
# Out:
# 72

# %%
# 연습문제
m = 12
print(int((0.2467 * m) + 4.159))
# Out:
# 7

# %%
# 심사문제
ap = 102
print( ap * 0.6 + 225)
# Out:
# 286.2
